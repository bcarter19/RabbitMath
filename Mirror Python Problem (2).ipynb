# %% [markdown]
# ## Mirrors Project - Question #3

# %%
# --------IMPORTING LIBRARIES--------
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# --------FORMATTING THE DISPLAY--------

# Setting the size of the display window
plt.figure(figsize = (7, 7))

# Setting the axes sizes
plt.xlim((-0.8, 1.4))
plt.ylim((-1.4, 0.8))

# Removing axes markers
plt.xticks([])
plt.yticks([])

# Create plot title
plt.title('Mirror Diagram')

# We do not want grid or axes lines so we left out those formatting lines we saw in the manual.


# --------PLOTTING POINTS AND FUNCTIONS--------

# Plot the vertex at the origin with a black dot
plt.plot(0, 0, 'b.')

# Will will need to convert our angles in degrees to radians. 
# We can input the angle value into the function math.radians().

# Plot your position and images with red circles
positionAndImages = [(0, -1), ((math.radians(320)), np.sin(math.radians(320))), (np.cos(math.radians(370)), np.sin(math.radians(370)))]
positionAndImagesX = [0, np.cos(math.radians(320)), np.cos(math.radians(370))]
positionAndImagesY = [-1, np.sin(math.radians(320)), np.sin(math.radians(370))]
plt.plot(positionAndImagesX, positionAndImagesY, 'ro')

# To plot the straight lines we will connect points instead of using functions

# Plot mirrors by connecting points to vertex with solid black lines
list1 = [(0, 0), (1.3*np.cos(math.radians(245)), 1.3*np.sin(math.radians(245)))]
X1 = [0, 1.3*np.cos(math.radians(245))]
Y1 = [0, 1.3*np.sin(math.radians(245))]
plt.plot(X1, Y1, 'k-')

list2 = [(0, 0), (1.3*np.cos(math.radians(295)), 1.3*np.sin(math.radians(295)))]
X2 = [0, 1.3*np.cos(math.radians(295))]
Y2 = [0, 1.3*np.sin(math.radians(295))]
plt.plot(X2, Y2, 'k-')

list3 = [(0, 0), (1.3*np.cos(math.radians(345)), 1.3*np.sin(math.radians(345)))]
X3 = [0, 1.3*np.cos(math.radians(345))]
Y3 = [0, 1.3*np.sin(math.radians(345))]
plt.plot(X3, Y3, 'k-')

list4 = [(0, 0), (1.3*np.cos(math.radians(395)), 1.3*np.sin(math.radians(395)))]
X4 = [0, 1.3*np.cos(math.radians(395))]
Y4 = [0, 1.3*np.sin(math.radians(395))]
plt.plot(X4, Y4, 'k-')


# Plot the lines between your position/images and the vertex with black dashed lines
list5 = [(0, 0), (np.cos(math.radians(270)), np.sin(math.radians(270)))]
X5 = [0, np.cos(math.radians(270))]
Y5 = [0, np.sin(math.radians(270))]
plt.plot(X5, Y5, 'k--')

list6 = [(0, 0), (np.cos(math.radians(320)), np.sin(math.radians(320)))]
X6 = [0, np.cos(math.radians(320))]
Y6 = [0, np.sin(math.radians(320))]
plt.plot(X6, Y6, 'k--')

list7 = [(0, 0), (np.cos(math.radians(370)), np.sin(math.radians(370)))]
X7 = [0, np.cos(math.radians(370))]
Y7 = [0, np.sin(math.radians(370))]
plt.plot(X7, Y7, 'k--')

# Plot the lines between your position and your images with blue dashed lines
list8 = [(np.cos(math.radians(270)), np.sin(math.radians(270))), (np.cos(math.radians(370)), np.sin(math.radians(370)))]
X8 = [np.cos(math.radians(270)), np.cos(math.radians(370))]
Y8 = [np.sin(math.radians(270)), np.sin(math.radians(370))]
plt.plot(X8, Y8, 'b--')

list9 = [(np.cos(math.radians(270)), np.sin(math.radians(270))), (np.cos(math.radians(320)), np.sin(math.radians(320)))]
X9 = [np.cos(math.radians(270)), np.cos(math.radians(320))]
Y9 = [np.sin(math.radians(270)), np.sin(math.radians(320))]
plt.plot(X9, Y9, 'b--')


# --------ADDING TEXT TO THE PLOT--------

# Label the images
plt.text((np.cos(math.radians(320)) + 0.05), np.sin(math.radians(320)) - 0.05, 'Image #1')
plt.text(np.cos(math.radians(370)) + 0.05, np.sin(math.radians(370) -0.05), 'Image #2')

# Include information on the angles of the lines 
plt.text(-0.7, 0.7, 'All angles between lines from the vertex are 25 degrees.')


plt.show()
